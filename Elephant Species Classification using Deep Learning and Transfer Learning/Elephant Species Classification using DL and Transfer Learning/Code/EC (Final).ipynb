# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
print('GPUs available:', len(tf.config.list_physical_devices('GPU')))
print(tf.config.list_physical_devices('GPU'))
# Out:
# GPUs available: 1
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
## Mount the Google Drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
train_path = '/content/drive/MyDrive/Krish AI/Elephant Classification/train'
test_path = '/content/drive/MyDrive/Krish AI/Elephant Classification/test'

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    zoom_range=0.2,
    horizontal_flip=True
)

# %%
test_datagen = ImageDataGenerator(rescale=1./255)

# %%
training_set = train_datagen.flow_from_directory(
    '/content/drive/MyDrive/Krish AI/Elephant Classification/train',
    target_size=(224,224),
    batch_size=32,
    class_mode='categorical'
)
# Out:
# Found 840 images belonging to 2 classes.

# %%
test_set = test_datagen.flow_from_directory(
    '/content/drive/MyDrive/Krish AI/Elephant Classification/test',
    target_size=(224,224),
    batch_size=32,
    class_mode='categorical'
)
# Out:
# Found 188 images belonging to 2 classes.

# %%
print("Class Indices:", training_set.class_indices)
# Out:
# Class Indices: {'African': 0, 'Asian': 1}

# %% [markdown]
# ## Model Building

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization

model = Sequential()

#Block 1
model.add(Conv2D(32, (3,3), activation='relu', input_shape=(224,224,3)))
model.add(BatchNormalization())
model.add(MaxPooling2D((2,2)))

#Block 2
model.add(Conv2D(64, (3,3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2,2)))

#Block 3
model.add(Conv2D(128, (3,3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2,2)))

#Block 4
model.add(Conv2D(256, (3,3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2,2)))

#Flattening
model.add(Flatten())

#Dense Head
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.3))

model.add(Dense(2, activation='softmax'))

model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 222, 222, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 222, 222, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ...

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(
    training_set,
    validation_data=test_set,
    epochs=10
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 699s 26s/step - accuracy: 0.4992 - loss: 6.6020 - val_accuracy: 0.5319 - val_loss: 1.1236
# Epoch 2/10
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 18s 671ms/step - accuracy: 0.5415 - loss: 8.0998 - val_accuracy: 0.4947 - val_loss: 4.1841
# Epoch 3/10
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 16s 581ms/step - accuracy: 0.5340 - loss: 7.4206 - val_accuracy: 0.4734 - val_loss: 5.9664
# Epoch 4/10
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 15s 571ms/step - accuracy: 0.5387 - loss: 5.6646 - val_accuracy: 0.4894 - val_loss: 1.2710
# Epoch 5/10
# ...

# %%
import json

model.save("/content/drive/MyDrive/Krish AI/Elephant Classification/base_model.h5")

with open("/content/drive/MyDrive/Krish AI/Elephant Classification/class_indices.json", "w") as f:
  json.dump(training_set.class_indices, f)

print("Saved model and class labels")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Saved model and class labels

# %%
history_2 = model.fit(
    training_set,
    validation_data=test_set,
    epochs=100
)
# Out:
# Epoch 1/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 17s 621ms/step - accuracy: 0.5457 - loss: 1.3952 - val_accuracy: 0.6117 - val_loss: 0.6996
# Epoch 2/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 22s 678ms/step - accuracy: 0.5420 - loss: 1.2617 - val_accuracy: 0.5053 - val_loss: 0.7792
# Epoch 3/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 16s 582ms/step - accuracy: 0.5496 - loss: 1.0817 - val_accuracy: 0.5160 - val_loss: 0.7495
# Epoch 4/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 16s 593ms/step - accuracy: 0.5274 - loss: 1.0452 - val_accuracy: 0.5000 - val_loss: 0.7462
# Epoch 5/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 16s 601ms/step - accuracy: 0.5717 - loss: 0.8561 - val_accuracy: 0.6011 - val_loss: 0.6815
# Epoch 6/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 16s 620ms/step - accuracy: 0.5369 - loss: 0.9229 - val_accuracy: 0.5372 - val_loss: 0.7099
# Epoch 7/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 17s 624ms/step - accuracy: 0.5409 - loss: 0.8872 - val_accuracy: 0.6064 - val_loss: 0.6786
# Epoch 8/100
# ...

# %%
import json

model.save("/content/drive/MyDrive/Krish AI/Elephant Classification/base_model2.h5")

with open("/content/drive/MyDrive/Krish AI/Elephant Classification/class_indices2.json", "w") as f:
  json.dump(training_set.class_indices, f)

print("Saved model and class labels")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Saved model and class labels

# %% [markdown]
# ## Transfer Learning

# %%
# MobileNetV2

from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

# %%
# Load the pre-trained base
base = MobileNetV2(
    input_shape=(224,224,3),
    include_top=False,
    weights='imagenet'
)

base.trainable=False

x = base.output
x = GlobalAveragePooling2D()(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.4)(x)
outputs = Dense(training_set.num_classes, activation = 'softmax')(x)

model_tf = Model(inputs=base.input, outputs=outputs)

model_tf.compile(
    optimizer='Adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model_tf.summary()
# Out:
# Model: "functional_18"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv1 (Conv2D)      │ (None, 112, 112,  │        864 │ input_layer_2[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn_Conv1            │ (None, 112, 112,  │        128 │ Conv1[0][0]       │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...

# %%
history_tf = model_tf.fit(
    training_set,
    validation_data=test_set,
    epochs=20
)
# Out:
# Epoch 1/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 16s 609ms/step - accuracy: 0.7780 - loss: 0.4376 - val_accuracy: 0.8245 - val_loss: 0.3801
# Epoch 2/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 17s 633ms/step - accuracy: 0.8046 - loss: 0.4242 - val_accuracy: 0.8723 - val_loss: 0.3742
# Epoch 3/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 15s 570ms/step - accuracy: 0.8231 - loss: 0.4128 - val_accuracy: 0.8564 - val_loss: 0.3501
# Epoch 4/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 15s 567ms/step - accuracy: 0.8138 - loss: 0.4348 - val_accuracy: 0.8245 - val_loss: 0.3721
# Epoch 5/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 15s 574ms/step - accuracy: 0.7755 - loss: 0.4329 - val_accuracy: 0.8298 - val_loss: 0.3815
# Epoch 6/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 15s 568ms/step - accuracy: 0.8099 - loss: 0.4207 - val_accuracy: 0.8351 - val_loss: 0.3696
# Epoch 7/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 16s 580ms/step - accuracy: 0.7944 - loss: 0.4647 - val_accuracy: 0.8564 - val_loss: 0.3671
# Epoch 8/20
# ...

# %% [markdown]
# ## Hyper Parameter Optimization on MobileNetV2

# %%
# !pip install -U keras-tuner  # If not already installed
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.4/129.4 kB 6.4 MB/s eta 0:00:00
# ...

# %%
# Recommended: Hyperparameter Optimization using KerasTuner (better integration with Keras/TensorFlow)



import keras_tuner as kt
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

# Assume training_set and test_set are your data generators (flow_from_directory, etc.)
# KerasTuner works seamlessly with generators and validation_data

num_classes = training_set.num_classes

def build_model(hp):
    base = MobileNetV2(
        input_shape=(224, 224, 3),
        include_top=False,
        weights='imagenet'
    )
    base.trainable = False  # Start with frozen base; can add fine-tuning later

    x = base.output
    x = GlobalAveragePooling2D()(x)

    dense_units = hp.Int('dense_units', min_value=128, max_value=512, step=64)
    x = Dense(dense_units, activation='relu')(x)

    dropout_rate = hp.Float('dropout_rate', min_value=0.2, max_value=0.6, step=0.1)
    x = Dropout(dropout_rate)(x)

    outputs = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs=base.input, outputs=outputs)

    learning_rate = hp.Float('learning_rate', min_value=1e-5, max_value=1e-3, sampling='log')
    model.compile(
        optimizer=Adam(learning_rate=learning_rate),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

    return model

# Use RandomSearch (or BayesianOptimization, Hyperband for faster)
tuner = kt.RandomSearch(
    build_model,
    objective='val_accuracy',
    max_trials=20,              # Number of different hyperparameter combinations to try
    executions_per_trial=1,     # Can increase for more robust evaluation
    directory='tuner_dir',
    project_name='mobilenetv2_tune'
)

# Optional: Early stopping callback
from tensorflow.keras.callbacks import EarlyStopping
early_stop = EarlyStopping(monitor='val_accuracy', patience=5, restore_best_weights=True)

# Search!
tuner.search(
    training_set,
    validation_data=test_set,
    epochs=30,                  # Max epochs per trial; early stopping will halt early
    callbacks=[early_stop]
)

# Results
best_model = tuner.get_best_models(num_models=1)[0]
best_hyperparameters = tuner.get_best_hyperparameters(num_trials=1)[0]

print("Best hyperparameters:")
print(best_hyperparameters.values)

print("Best validation accuracy from search:", tuner.oracle.get_best_trials(1)[0].score)

# You can now further train the best_model if needed
# best_model.fit(training_set, validation_data=test_set, epochs=20)

# Or evaluate
# best_model.evaluate(test_set)
# Out:
# Trial 20 Complete [00h 04m 33s]
# val_accuracy: 0.8510638475418091
#
# Best val_accuracy So Far: 0.8989361524581909
# Total elapsed time: 01h 32m 18s
# Best hyperparameters:
# {'dense_units': 256, 'dropout_rate': 0.30000000000000004, 'learning_rate': 0.0001566830617436793}
# Best validation accuracy from search: 0.8989361524581909
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py:802: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 10 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
#Get the best single model (already loaded with its best weights)

#best_model = tuner.get_best_models(num_models=1)[0]

best_model.save_weights('/content/drive/MyDrive/Krish AI/Elephant Classification/best_mobilenetv2.weights.h5')

# %% [markdown]
# ## Xception

# %%
from tensorflow.keras.applications import Xception
from tensorflow.keras.applications.xception import preprocess_input
from tensorflow.keras.layers import GlobalMaxPooling2D, Dense, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

base = Xception(
    input_shape=(299,299,3),
    include_top=False,
    weights='imagenet'
)

base.trainable=False

x = base.output
x = GlobalMaxPooling2D()(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.4)(x)
outputs = Dense(training_set.num_classes, activation = 'softmax')(x)

model_xc = Model(inputs=base.input, outputs=outputs)

model_xc.compile(
    optimizer='Adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model_xc.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 299, 299,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv1        │ (None, 149, 149,  │        864 │ input_layer_1[0]… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv1_bn     │ (None, 149, 149,  │        128 │ block1_conv1[0][… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...

# %%
training_set_xc = train_datagen.flow_from_directory(
    train_path,
    target_size=(299,299),
    batch_size=32,
    class_mode='categorical'
)

test_set_xc = test_datagen.flow_from_directory(
    test_path,
    target_size=(299,299),
    batch_size=32,
    class_mode='categorical'
)

history_xc = model_xc.fit(
    training_set_xc,
    validation_data = test_set_xc,
    epochs=20
)
# Out:
# Found 840 images belonging to 2 classes.
# Found 188 images belonging to 2 classes.
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 305s 10s/step - accuracy: 0.5870 - loss: 1.4040 - val_accuracy: 0.8723 - val_loss: 0.3716
# Epoch 2/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 25s 935ms/step - accuracy: 0.7209 - loss: 0.5690 - val_accuracy: 0.8830 - val_loss: 0.3253
# Epoch 3/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 25s 925ms/step - accuracy: 0.7779 - loss: 0.5269 - val_accuracy: 0.8989 - val_loss: 0.3741
# Epoch 4/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 26s 935ms/step - accuracy: 0.7282 - loss: 0.5622 - val_accuracy: 0.8670 - val_loss: 0.3562
# ...
